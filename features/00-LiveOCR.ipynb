# %%
from pytesseract import Output
import pytesseract
import argparse
import cv2

# %%
cap = cv2.VideoCapture(0)

while(True):
    ret, image = cap.read()
    
    #image = cv2.imread(args["image"])
    rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = pytesseract.image_to_data(rgb, output_type=Output.DICT)

    for i in range(0, len(results["text"])):
        
        # extract the bounding box coordinates of the text region from
        # the current result
        x = results["left"][i]
        y = results["top"][i]
        w = results["width"][i]
        h = results["height"][i]
        # extract the OCR text itself along with the confidence of the
        # text localization
        
        text = results["text"][i]
        conf = int(results["conf"][i])

        # filter out weak confidence text localizations
        if conf > 0.3:
            
            # display the confidence and text to our terminal
            print("Confidence: {}".format(conf))
            print("Text: {}".format(text))
            print("")
            
            # strip out non-ASCII text so we can draw the text on the image
            # using OpenCV, then draw a bounding box around the text along
            # with the text itself
            text = "".join([c if ord(c) < 128 else "" for c in text]).strip()
            cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.putText(image, text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX,
                1.2, (0, 0, 255), 3)
            
    # show the output image
    cv2.imshow("Image", image)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
    #cv2.waitKey(0)

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 35
# Text: rp
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 42
# Text: “8
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 41
# Text: st
#
# Confidence: 96
# Text: UBS
#
# Confidence: 95
# Text:
#
# Confidence: 75
# Text: P
#
# Confidence: 71
# Text: cP
#
# Confidence: 80
# Text: 4473
#
# Confidence: 58
# Text: =
#
# Confidence: 67
# Text: 10024
#
# Confidence: 87
# Text: /
#
# Confidence: 96
# Text: 0537
#
# Confidence: 17
# Text: geass
#
# Confidence: 19
# Text: A
#
# Confidence: 78
# Text: A
#
# Confidence: 42
# Text: Prony
#
# Confidence: 53
# Text: 2"
#
# Confidence: 96
# Text: Personnel
#
# Confidence: 23
# Text: eee
#
# Confidence: 96
# Text: Monsieur
#
# Confidence: 92
# Text: Maél
#
# Confidence: 96
# Text: Fabien
#
# Confidence: 96
# Text: Avenue
#
# Confidence: 96
# Text: du
#
# Confidence: 96
# Text: Midi
#
# Confidence: 96
# Text: 15
#
# Confidence: 96
# Text: 1820
#
# Confidence: 96
# Text: Montreux
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 34
# Text: NN
#
# Confidence: 49
# Text: At
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 7
# Text: UBS
#
# Confidence: 95
# Text:
#
# Confidence: 92
# Text: 558
#
# Confidence: 87
# Text: /
#
# Confidence: 84
# Text: 0024
#
# Confidence: 86
# Text: /
#
# Confidence: 86
# Text: 0537
#
# Confidence: 79
# Text: A
#
# Confidence: 59
# Text: “PRIORITY
#
# Confidence: 80
# Text: 2
#
# Confidence: 80
# Text: /
#
# Confidence: 31
# Text: fr
#
# Confidence: 30
# Text: /T01
#
# Confidence: 94
# Text: Personnel
#
# Confidence: 96
# Text: Monsieur
#
# Confidence: 82
# Text: ES
#
# Confidence: 91
# Text: Maél
#
# Confidence: 96
# Text: Fabien
#
# Confidence: 96
# Text: Avenue
#
# Confidence: 96
# Text: du
#
# Confidence: 96
# Text: Midi
#
# Confidence: 96
# Text: 15
#
# Confidence: 96
# Text: 1820
#
# Confidence: 96
# Text: Montreux
#
# Confidence: 95
# Text:
#
# Confidence: 35
# Text: é
#
# Confidence: 96
# Text: UBS
#
# Confidence: 16
# Text: Pe
#
# Confidence: 33
# Text: eee
#
# Confidence: 59
# Text: |
#
# Confidence: 52
# Text: =
#
# Confidence: 37
# Text: Ooms
#
# Confidence: 77
# Text: :
#
# Confidence: 2
# Text: [PLP
#
# Confidence: 24
# Text: Skit
#
# Confidence: 58
# Text: a
#
# Confidence: 17
# Text: Lown
#
# Confidence: 4
# Text: corte
#
# Confidence: 39
# Text: _|
#
# Confidence: 5
# Text: AL
#
# Confidence: 52
# Text: Y
#
# Confidence: 30
# Text: ie
#
# Confidence: 27
# Text: ‘Tet
#
# Confidence: 94
# Text: Personnel
#
# Confidence: 11
# Text: me
#
# Confidence: 96
# Text: Monsieur
#
# Confidence: 81
# Text: Maél
#
# Confidence: 96
# Text: Fabien
#
# Confidence: 96
# Text: Avenue
#
# Confidence: 96
# Text: du
#
# Confidence: 90
# Text: Midi
#
# Confidence: 90
# Text: 15
#
# Confidence: 96
# Text: 1820
#
# Confidence: 96
# Text: Montreux
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text: 10
#
# Confidence: 96
# Text: mars
#
# Confidence: 96
# Text: 2020
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 93
# Text: UBS
#
# Confidence: 64
# Text: Switzerlane
#
# Confidence: 59
# Text: AS
#
# Confidence: 20
# Text: bs
#
# Confidence: 96
# Text: UBS
#
# Confidence: 95
# Text: CLS
#
# Confidence: 94
# Text: Digital
#
# Confidence: 94
# Text: Banking
#
# Confidence: 89
# Text: Case
#
# Confidence: 22
# Text: posiale
#
# Confidence: 81
# Text: CH-8098
#
# Confidence: 44
# Text: Zunict
#
# Confidence: 87
# Text: ubs.com/digital
#
# Confidence: 71
# Text: 447
#
# Confidence: 91
# Text: 558
#
# Confidence: 91
# Text: /
#
# Confidence: 89
# Text: 0024
#
# Confidence: 88
# Text: /
#
# Confidence: 92
# Text: 0537
#
# Confidence: 54
# Text: PP.
#
# Confidence: 12
# Text: Sas
#
# Confidence: 94
# Text: A
#
# Confidence: 31
# Text: mee
#
# Confidence: 95
# Text: ITY
#
# Confidence: 35
# Text: 2
#
# Confidence: 35
# Text: /
#
# Confidence: 42
# Text: fr
#
# Confidence: 42
# Text: /T04
#
# Confidence: 30
# Text: Persoxwvel
#
# Confidence: 33
# Text: wens
#
# Confidence: 58
# Text: Morseuw
#
# Confidence: 84
# Text: Fabien
#
# Confidence: 38
# Text: byetue
#
# Confidence: 40
# Text: Gs
#
# Confidence: 61
# Text: Vidi
#
# Confidence: 82
# Text: 15
#
# Confidence: 93
# Text: 1820
#
# Confidence: 50
# Text: Montreux
#
# Confidence: 95
# Text:
#
# Confidence: 30
# Text: 60
#
# Confidence: 24
# Text: eas.
#
# Confidence: 30
# Text: boo
#
# Confidence: 39
# Text: ge
#
# Confidence: 93
# Text: UDO
#
# Confidence: 95
# Text:
#
# Confidence: 26
# Text: a
#
# Confidence: 48
# Text: se
#
# Confidence: 12
# Text: goa
#
# Confidence: 21
# Text: ess7
#
# Confidence: 53
# Text: PLP.
#
# Confidence: 25
# Text: ict
#
# Confidence: 64
# Text: _|
#
# Confidence: 10
# Text: LPP.
#
# Confidence: 69
# Text: |
#
# Confidence: 7
# Text: Aceon
#
# Confidence: 27
# Text: 28.101
#
# Confidence: 59
# Text: =
#
# Confidence: 21
# Text: oe
#
# Confidence: 82
# Text: Maél
#
# Confidence: 96
# Text: Fabien
#
# Confidence: 96
# Text: Avenue
#
# Confidence: 96
# Text: du
#
# Confidence: 96
# Text: Midi
#
# Confidence: 96
# Text: 15
#
# Confidence: 96
# Text: 1820
#
# Confidence: 96
# Text: Montreux
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text: 10
#
# Confidence: 96
# Text: mars
#
# Confidence: 96
# Text: 2020
#
# Confidence: 54
# Text: gge
#
# Confidence: 93
# Text: UDO
#
# Confidence: 34
# Text: ee
#
# Confidence: 30
# Text: oe
#
# Confidence: 63
# Text: |
#
# Confidence: 80
# Text: 4473
#
# Confidence: 23
# Text: 10024
#
# Confidence: 65
# Text: |
#
# Confidence: 81
# Text: 0537
#
# Confidence: 34
# Text: ee
#
# Confidence: 30
# Text: oe
#
# Confidence: 63
# Text: |
#
# Confidence: 96
# Text: Bale
#
# Confidence: 49
# Text: =
#
# Confidence: 5
# Text: LE
#
# Confidence: 32
# Text: pale
#
# Confidence: 34
# Text: __|
#
# Confidence: 12
# Text: ies
#
# Confidence: 14
# Text: to1
#
# Confidence: 23
# Text: i
#
# Confidence: 68
# Text: fr/
#
# Confidence: 48
# Text: 01
#
# Confidence: 94
# Text: Personnel
#
# Confidence: 96
# Text: Monsieur
#
# Confidence: 82
# Text: Maél
#
# Confidence: 96
# Text: Fabien
#
# Confidence: 96
# Text: Avenue
#
# Confidence: 96
# Text: du
#
# Confidence: 96
# Text: Midi
#
# Confidence: 88
# Text: 15
#
# Confidence: 96
# Text: 1820
#
# Confidence: 96
# Text: Montreux
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: 10
#
# Confidence: 96
# Text: mars
#
# Confidence: 96
# Text: 2020
#
# Confidence: 96
# Text: UBS
#
# Confidence: 96
# Text: Digital
#
# Confidence: 7
# Text: Banking:
#
# Confidence: 58
# Text: Card
#
# Confidence: 18
# Text: nc
#
# Confidence: 56
# Text: 1.
#
# Confidence: 44
# Text: CLS
#
# Confidence: 57
# Text: Digna’
#
# Confidence: 62
# Text: Banking
#
# Confidence: 93
# Text: Case
#
# Confidence: 77
# Text: postale
#
# Confidence: 86
# Text: CH-8098
#
# Confidence: 96
# Text: Zurich
#
# Confidence: 74
# Text: ubs.com/digita’
#
# Confidence: 95
# Text:
#
# Confidence: 43
# Text: ege
#
# Confidence: 18
# Text: UDY
#
# Confidence: 38
# Text: cpaays
#
# Confidence: 91
# Text: 558
#
# Confidence: 90
# Text: /
#
# Confidence: 90
# Text: 0024
#
# Confidence: 92
# Text: /
#
# Confidence: 92
# Text: 0537
#
# Confidence: 44
# Text: P.P.
#
# Confidence: 74
# Text: Bale
#
# Confidence: 96
# Text: A
#
# Confidence: 39
# Text: XR
#
# Confidence: 24
# Text: ee
#
# Confidence: 48
# Text: 2/
#
# Confidence: 11
# Text: fr
#
# Confidence: 11
# Text: 101
#
# Confidence: 96
# Text: Avenue
#
# Confidence: 96
# Text: du
#
# Confidence: 96
# Text: Midi
#
# Confidence: 96
# Text: 15
#
# Confidence: 96
# Text: 1820
#
# Confidence: 96
# Text: Montreux
#
# Confidence: 96
# Text: 10
#
# Confidence: 96
# Text: mars
#
# Confidence: 96
# Text: 2020
#
# Confidence: 77
# Text: UES
#
# Confidence: 62
# Text: Digital
#
# Confidence: 20
# Text: Pe
#
# Confidence: 33
# Text: EE
#
# Confidence: 93
# Text: Case
#
# Confidence: 79
# Text: postale
#
# Confidence: 92
# Text: CH-8098
#
# Confidence: 93
# Text: Zurich
#
# Confidence: 19
# Text: ubs.com/digital
#
# Confidence: 57
# Text: =
#
# Confidence: 95
# Text:
#
# Confidence: 24
# Text: tae
#
# Confidence: 13
# Text: age
#
# Confidence: 55
# Text: UDY
#
# Confidence: 40
# Text: ps]
#
# Confidence: 83
# Text: P.
#
# Confidence: 40
# Text: ps]
#
# Confidence: 32
# Text: eee
#
# Confidence: 79
# Text: CH-4002
#
# Confidence: 88
# Text: Bale
#
# Confidence: 49
# Text: AR
#
# Confidence: 29
# Text: “PRIORITY
#
# Confidence: 12
# Text: [Et
#
# Confidence: 61
# Text: |
#
# Confidence: 16
# Text: PXpaioniry
#
# Confidence: 19
# Text: At
#
# Confidence: 13
# Text: aoe
#
# Confidence: 71
# Text: Maél
#
# Confidence: 96
# Text: Fabien
#
# Confidence: 96
# Text: Avenue
#
# Confidence: 96
# Text: du
#
# Confidence: 96
# Text: Midi
#
# Confidence: 96
# Text: 15
#
# Confidence: 96
# Text: 1820
#
# Confidence: 96
# Text: Montreux
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: 10
#
# Confidence: 96
# Text: mars
#
# Confidence: 96
# Text: 2020
#
# Confidence: 96
# Text: UBS
#
# Confidence: 74
# Text: Digital
#
# Confidence: 39
# Text: Accecc
#
# Confidence: 95
# Text: Card
#
# Confidence: 65
# Text: nt
#
# Confidence: 22
# Text: undies
#
# Confidence: 37
# Text: bo
#
# Confidence: 93
# Text: Case
#
# Confidence: 80
# Text: postale
#
# Confidence: 70
# Text: CH-8098
#
# Confidence: 70
# Text: Zurich
#
# Confidence: 59
# Text: ubs.com/digita’
#
# Confidence: 95
# Text:
# Confidence: 24
# Text: ainsi
#
# Confidence: 40
# Text: tas
#
# Confidence: 75
# Text: ege
#
# Confidence: 89
# Text: UDO
#
# Confidence: 96
# Text: Case
#
# Confidence: 85
# Text: postale
#
# Confidence: 92
# Text: CH-8098
#
# Confidence: 94
# Text: Zurich
#
# Confidence: 73
# Text: ubs.com/digita’
#
# Confidence: 89
# Text: PP.
#
# Confidence: 62
# Text: cP
#
# Confidence: 25
# Text: 4473
#
# Confidence: 13
# Text: ae
#
# Confidence: 94
# Text: A
#
# Confidence: 2
# Text: 2
#
# Confidence: 83
# Text: 2
#
# Confidence: 83
# Text: /
#
# Confidence: 53
# Text: fr
#
# Confidence: 53
# Text: /
#
# Confidence: 57
# Text: T04
#
# Confidence: 96
# Text: Personnel
#
# Confidence: 23
# Text: ;
#
# Confidence: 24
# Text: cd
#
# Confidence: 96
# Text: Monsieur
#
# Confidence: 90
# Text: Maél
#
# Confidence: 96
# Text: Fabien
#
# Confidence: 96
# Text: Avenue
#
# Confidence: 96
# Text: du
#
# Confidence: 96
# Text: Midi
#
# Confidence: 96
# Text: 15
#
# Confidence: 96
# Text: 1820
#
# Confidence: 96
# Text: Montreux
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: 10
#
# Confidence: 96
# Text: mars
#
# Confidence: 96
# Text: 2020
#
# Confidence: 9
# Text: ne
#
# Confidence: 27
# Text: ae
#
# Confidence: 39
# Text: ae
#
# Confidence: 15
# Text: eee
#
# Confidence: 29
# Text: ee,
#
# Confidence: 95
# Text:
#
# Confidence: 93
# Text: Case
#
# Confidence: 53
# Text: postale
#
# Confidence: 89
# Text: CH-8098
#
# Confidence: 87
# Text: Zurich
#
# Confidence: 61
# Text: ubs.com/digita!
#
# Confidence: 93
# Text: 558
#
# Confidence: 93
# Text: /
#
# Confidence: 85
# Text: 0024
#
# Confidence: 85
# Text: /
#
# Confidence: 96
# Text: 0537
#
# Confidence: 23
# Text: a
#
# Confidence: 38
# Text: bas
#
# Confidence: 85
# Text: P.
#
# Confidence: 27
# Text: Peas
#
# Confidence: 23
# Text: ee.
#
# Confidence: 81
# Text: 3
#
# Confidence: 96
# Text: Avenue
#
# Confidence: 96
# Text: du
#
# Confidence: 96
# Text: Midi
#
# Confidence: 84
# Text: 15
#
# Confidence: 96
# Text: 1820
#
# Confidence: 95
# Text: Montreux
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: 10
#
# Confidence: 96
# Text: mars
#
# Confidence: 96
# Text: 2020
#
# Confidence: 24
# Text: ree
#
# Confidence: 29
# Text: a
#
# Confidence: 24
# Text: ee
#
# Confidence: 19
# Text: a
#
# Confidence: 16
# Text: sence.”
#
# Confidence: 15
# Text: Ant
#
# Confidence: 28
# Text: ect!
#
# Confidence: 29
# Text: Soe
#
# Confidence: 28
# Text: we
#
# Confidence: 6
# Text: UY
#
# Confidence: 87
# Text: P.
#
# Confidence: 42
# Text: Pp
#
# Confidence: 78
# Text: cP
#
# Confidence: 81
# Text: 4473
#
# Confidence: 16
# Text: oa
#
# Confidence: 70
# Text: /
#
# Confidence: 96
# Text: 0537
#
# Confidence: 13
# Text: pase
#
# Confidence: 31
# Text: Pinon
#
# Confidence: 58
# Text: 2/fr/
#
# Confidence: 44
# Text: 01
#
# Confidence: 31
# Text: ea
#
# Confidence: 96
# Text: Personnel
#
# Confidence: 38
# Text: ge
#
# Confidence: 96
# Text: Monsieur
#
# Confidence: 71
# Text: Maél
#
# Confidence: 96
# Text: Fabien
#
# Confidence: 96
# Text: Avenue
#
# Confidence: 96
# Text: du
#
# Confidence: 96
# Text: Midi
#
# Confidence: 82
# Text: 15
#
# Confidence: 96
# Text: 1820
#
# Confidence: 96
# Text: Montreux
#
# Confidence: 96
# Text: 10
#
# Confidence: 96
# Text: mars
#
# Confidence: 96
# Text: 2020
#
# Confidence: 40
# Text: LRG
#
# Confidence: 32
# Text: RantWinne
#
# Confidence: 30
# Text: Gite
#
# Confidence: 46
# Text: ms
#
# Confidence: 56
# Text: ccc
#
# Confidence: 93
# Text: Case
#
# Confidence: 61
# Text: postale
#
# Confidence: 61
# Text: CH-8098
#
# Confidence: 95
# Text: Zurich
#
# Confidence: 40
# Text: ubs.com/digita!
#
# Confidence: 95
# Text:
#
# Confidence: 14
# Text: Pn
#
# Confidence: 45
# Text: itn
#
# Confidence: 29
# Text: Ns”
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 30
# Text: 7p
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 26
# Text: <p
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: RESEARCH
#
# Confidence: 10
# Text: Institute
#
# Confidence: 54
# Text: Wf
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: RESEARCH
#
# Confidence: 55
# Text: Institute
#
# Confidence: 48
# Text: Wf
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text: RESEARCH
#
# Confidence: 51
# Text: INstiture
#
# Confidence: 46
# Text: Wf
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: RESEARCH
#
# Confidence: 20
# Text: INstitute
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: RESEARCH
#
# Confidence: 94
# Text: INSTITUTE
#
# Confidence: 58
# Text: i
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 92
# Text: e
#
# Confidence: 95
# Text: for
#
# Confidence: 79
# Text: Society
#
# Confidence: 96
# Text: Artificial
#
# Confidence: 77
# Text: Intelligenc
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 92
# Text: e
#
# Confidence: 96
# Text: for
#
# Confidence: 93
# Text: Society
#
# Confidence: 93
# Text: Artificial
#
# Confidence: 90
# Text: Intelligenc
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 41
# Text: +
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 6
# Text: :
#
# Confidence: 18
# Text: *
#
# Confidence: 32
# Text: ae
#
# Confidence: 27
# Text: oe
#
# Confidence: 22
# Text: yO
#
# Confidence: 79
# Text: 4
#
# Confidence: 21
# Text: eo
#
# Confidence: 64
# Text: 1!
#
# Confidence: 50
# Text: ti
#
# Confidence: 54
# Text: 2
#
# Confidence: 47
# Text: 7
#
# Confidence: 35
# Text: ty
#
# Confidence: 26
# Text: ”
#
# Confidence: 50
# Text: 7
#
# Confidence: 38
# Text: tm
#
# Confidence: 37
# Text: 7
#
# Confidence: 81
# Text: ry
#
# Confidence: 27
# Text: POD
#
# Confidence: 56
# Text: 1
#
# Confidence: 51
# Text: 77
#
# Confidence: 40
# Text: my
#
# Confidence: 30
# Text: ie
#
# Confidence: 31
# Text: EL
#
# Confidence: 22
# Text: Ls
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 92
# Text: rtificial
#
# Confidence: 96
# Text: Intelligence
#
# Confidence: 96
# Text: for
#
# Confidence: 96
# Text: Society
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 86
# Text: rtificial
#
# Confidence: 96
# Text: Intelligence
#
# Confidence: 96
# Text: for
#
# Confidence: 96
# Text: Society
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: Artificial
#
# Confidence: 96
# Text: Intelligence
#
# Confidence: 96
# Text: for
#
# Confidence: 96
# Text: Society
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: Artificial
#
# Confidence: 96
# Text: Intelligence
#
# Confidence: 96
# Text: for
#
# Confidence: 96
# Text: Society
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: Artificial
#
# Confidence: 96
# Text: Intelligence
#
# Confidence: 96
# Text: for
#
# Confidence: 96
# Text: Society
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 96
# Text: Artificial
#
# Confidence: 96
# Text: Intelligence
#
# Confidence: 96
# Text: for
#
# Confidence: 96
# Text: Society
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 56
# Text: ev
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
#
# Confidence: 95
# Text:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-80d451f91aa6> in <module>
#       6     #image = cv2.imread(args["image"])
#       7     rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# ----> 8     results = pytesseract.image_to_data(rgb, output_type=Output.DICT)
#       9
#      10     for i in range(0, len(results["text"])):
#
# ~/anaconda3/lib/python3.7/site-packages/pytesseract/pytesseract.py in image_to_data(image, lang, config, nice, output_type, timeout, pandas_config)
#     425         Output.DICT: lambda: file_to_dict(run_and_get_output(*args), '\t', -1),
#     426         Output.STRING: lambda: run_and_get_output(*args),
# --> 427     }[output_type]()
#     428
#     429
#
# ~/anaconda3/lib/python3.7/site-packages/pytesseract/pytesseract.py in <lambda>()
#     423             args + [True], pandas_config,
#     424         ),
# --> 425         Output.DICT: lambda: file_to_dict(run_and_get_output(*args), '\t', -1),
#     426         Output.STRING: lambda: run_and_get_output(*args),
#     427     }[output_type]()
#
# ~/anaconda3/lib/python3.7/site-packages/pytesseract/pytesseract.py in run_and_get_output(image, extension, lang, config, nice, timeout, return_bytes)
#     258         }
#     259
# --> 260         run_tesseract(**kwargs)
#     261         filename = kwargs['output_filename_base'] + extsep + extension
#     262         with open(filename, 'rb') as output_file:
#
# ~/anaconda3/lib/python3.7/site-packages/pytesseract/pytesseract.py in run_tesseract(input_filename, output_filename_base, extension, lang, config, nice, timeout)
#     232         raise TesseractNotFoundError()
#     233
# --> 234     with timeout_manager(proc, timeout) as error_string:
#     235         if proc.returncode:
#     236             raise TesseractError(proc.returncode, get_errors(error_string))
#
# ~/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.7/site-packages/pytesseract/pytesseract.py in timeout_manager(proc, seconds)
#      89     try:
#      90         if not seconds:
# ---> 91             yield proc.communicate()[1]
#      92             return
#      93
#
# ~/anaconda3/lib/python3.7/subprocess.py in communicate(self, input, timeout)
#     937
#     938             try:
# --> 939                 stdout, stderr = self._communicate(input, endtime, timeout)
#     940             except KeyboardInterrupt:
#     941                 # https://bugs.python.org/issue25942
#
# ~/anaconda3/lib/python3.7/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1679                         raise TimeoutExpired(self.args, orig_timeout)
#    1680
# -> 1681                     ready = selector.select(timeout)
#    1682                     self._check_timeout(endtime, orig_timeout)
#    1683
#
# ~/anaconda3/lib/python3.7/selectors.py in select(self, timeout)
#     413         ready = []
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#     417             return ready
#
# KeyboardInterrupt:
